# %% [markdown]
# # Churn Dataset for Broadband users

# %% [markdown]
# Objective: For this exercise, our aim is to find out if a broadband users churns or not

# %%
# Must be included at the beginning of each new notebook. Remember to change the app name.
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import *
spark = SparkSession.builder.appName('logistic_regression_churn').getOrCreate()

# If you're getting an error with numpy, please type 'sudo pip install numpy --user' into the EC2 console.
from pyspark.ml.classification import LogisticRegression

# Disable warnings, set Matplotlib inline plotting and load Pandas package
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import pandas as pd

# %%
# Read in the CSV data.
data = spark.read.csv('BROADBAND_CHURN_SPSS.csv',inferSchema=True,header=True)

# %%
# Print data schema and properties on the columns
data.printSchema()

# Print data columns.
data.columns
# Out:
# root
#  |-- FXD_ACCT_KEY: integer (nullable = true)
#  |-- CAL_DT_KEY: integer (nullable = true)
#  |-- CAL_MTH_KEY: integer (nullable = true)
#  |-- MTH_END_FLAG: string (nullable = true)
#  |-- OPENING_STATUS: string (nullable = true)
#  |-- CLOSING_STATUS: string (nullable = true)
#  |-- OPENING_SEGMENT: string (nullable = true)
#  |-- CLOSING_SEGMENT: string (nullable = true)
#  |-- TECHNOLOGY: string (nullable = true)
#  |-- OPENING_BASE: integer (nullable = true)
#  |-- ADDITIONS: integer (nullable = true)
#  |-- DISCONNECTS: integer (nullable = true)
#  |-- CLOSING_BASE: integer (nullable = true)
#  |-- GROSS_ADDS: integer (nullable = true)
#  |-- CHURN: integer (nullable = true)
#  |-- MIGRATIONS: integer (nullable = true)
#  |-- TITLE: string (nullable = true)
#  |-- SUBURB: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- POST_CODE: string (nullable = true)
#  |-- PYMNT_METHOD: string (nullable = true)
#  |-- SEG_KEY: integer (nullable = true)
#  |-- HIST_START_DTTM: string (nullable = true)
#  |-- HIST_END_DTTM: string (nullable = true)
#  |-- CURR_IND: string (nullable = true)
#  |-- PROD_KEY: integer (nullable = true)
#  |-- PROD_CD: string (nullable = true)
#  |-- PROD_DESCR: string (nullable = true)
#  |-- PROD_GRP_DESCR: string (nullable = true)
#  |-- PROD_TYPE: string (nullable = true)
#  |-- PROD_INTERNAL_DESCR: string (nullable = true)
#  |-- MLY_FEE_INCL_GST: double (nullable = true)
#  |-- CARE_CONTACT: integer (nullable = true)
#  |-- DATA_USAGE: integer (nullable = true)
# ['FXD_ACCT_KEY',
#  'CAL_DT_KEY',
#  'CAL_MTH_KEY',
#  'MTH_END_FLAG',
#  'OPENING_STATUS',
#  'CLOSING_STATUS',
#  'OPENING_SEGMENT',
#  'CLOSING_SEGMENT',
#  'TECHNOLOGY',
#  'OPENING_BASE',
#  'ADDITIONS',
#  'DISCONNECTS',
#  'CLOSING_BASE',
#  'GROSS_ADDS',
#  'CHURN',
#  'MIGRATIONS',
#  'TITLE',
#  'SUBURB',
#  'CITY',
#  'POST_CODE',
#  'PYMNT_METHOD',
#  'SEG_KEY',
#  'HIST_START_DTTM',
#  'HIST_END_DTTM',
#  'CURR_IND',
#  'PROD_KEY',
#  'PROD_CD',
#  'PROD_DESCR',
#  'PROD_GRP_DESCR',
#  'PROD_TYPE',
#  'PROD_INTERNAL_DESCR',
#  'MLY_FEE_INCL_GST',
#  'CARE_CONTACT',
#  'DATA_USAGE']

# %%
pd.DataFrame(data.take(5), columns=data.columns).transpose()
# Out:
#                                            0                       1  \
# FXD_ACCT_KEY                          212540                  215540
# CAL_DT_KEY                          20190831                20190831
# CAL_MTH_KEY                           201908                  201908
# MTH_END_FLAG                               Y                       Y
# OPENING_STATUS                        ACTIVE                  ACTIVE
# CLOSING_STATUS                        ACTIVE                  ACTIVE
# OPENING_SEGMENT                  RESIDENTIAL             RESIDENTIAL
# CLOSING_SEGMENT                  RESIDENTIAL             RESIDENTIAL
# TECHNOLOGY                               UFB                     UFB
# OPENING_BASE                               1                       1
# ADDITIONS                                  0                       0
# DISCONNECTS                                0                       0
# CLOSING_BASE                               1                       1
# GROSS_ADDS                                 0                       0
# CHURN                                      0                       0
# MIGRATIONS                                 0                       0
# TITLE                                   NULL                    NULL
# SUBURB                             DANNEMORA                WOOLSTON
# CITY                                AUCKLAND            CHRISTCHURCH
# POST_CODE                               2016                    8023
# PYMNT_METHOD                            Visa            Direct Debit
# SEG_KEY                                    1                       1
# HIST_START_DTTM              14/06/2019 0:00         24/05/2019 0:00
# HIST_END_DTTM                31/12/9999 0:00         31/12/9999 0:00
# CURR_IND                                   Y                       Y
# PROD_KEY                                2141                    1114
# PROD_CD                                  CON                    2DBD
# PROD_DESCR           Services under contract   OPay Monthly Discount
# PROD_GRP_DESCR                         OTHER                DISCOUNT
# PROD_TYPE                         SUPSERVICE              SUPSERVICE
# PROD_INTERNAL_DESCR                     NULL                    NULL
# MLY_FEE_INCL_GST                           0                     -10
# CARE_CONTACT                               0                       0
# DATA_USAGE                               100                     150
#
#                                          2  \
# FXD_ACCT_KEY                        213980
# CAL_DT_KEY                        20190831
# CAL_MTH_KEY                         201908
# MTH_END_FLAG                             Y
# OPENING_STATUS                      ACTIVE
# CLOSING_STATUS                      ACTIVE
# OPENING_SEGMENT                RESIDENTIAL
# CLOSING_SEGMENT                RESIDENTIAL
# TECHNOLOGY                            VDSL
# OPENING_BASE                             1
# ADDITIONS                                0
# DISCONNECTS                              0
# CLOSING_BASE                             1
# GROSS_ADDS                               0
# CHURN                                    0
# MIGRATIONS                               0
# TITLE                                 NULL
# SUBURB                          PAPATOETOE
# CITY                                  None
# POST_CODE                         AUCKLAND
# PYMNT_METHOD                          Visa
# SEG_KEY                                  1
# HIST_START_DTTM             4/08/2019 0:00
# HIST_END_DTTM              31/12/9999 0:00
# CURR_IND                                 Y
# PROD_KEY                              5051
# PROD_CD                               LOAN
# PROD_DESCR           2degrees Modem Rental
# PROD_GRP_DESCR                        RENT
# PROD_TYPE                       SUPSERVICE
# PROD_INTERNAL_DESCR                   NULL
# MLY_FEE_INCL_GST                         0
# CARE_CONTACT                             0
# DATA_USAGE                             200
#
#                                                                3  \
# FXD_ACCT_KEY                                              151459
# CAL_DT_KEY                                              20190831
# CAL_MTH_KEY                                               201908
# MTH_END_FLAG                                                   Y
# OPENING_STATUS                                            ACTIVE
# CLOSING_STATUS                                            ACTIVE
# OPENING_SEGMENT                                      RESIDENTIAL
# CLOSING_SEGMENT                                      RESIDENTIAL
# TECHNOLOGY                                                   UFB
# OPENING_BASE                                                   1
# ADDITIONS                                                      0
# DISCONNECTS                                                    0
# CLOSING_BASE                                                   1
# GROSS_ADDS                                                     0
# CHURN                                                          0
# MIGRATIONS                                                     0
# TITLE                                                       NULL
# SUBURB                                                    HOWICK
# CITY                                                    AUCKLAND
# POST_CODE                                                   2014
# PYMNT_METHOD                                                Visa
# SEG_KEY                                                        1
# HIST_START_DTTM                                   4/08/2018 0:00
# HIST_END_DTTM                                    31/12/9999 0:00
# CURR_IND                                                       Y
# PROD_KEY                                                    4852
# PROD_CD                                                      696
# PROD_DESCR           2degrees Broadband Unlimited Ultimate Fibre
# PROD_GRP_DESCR                                               UFB
# PROD_TYPE                                               PLANTYPE
# PROD_INTERNAL_DESCR                                  UFB 900/400
# MLY_FEE_INCL_GST                                             110
# CARE_CONTACT                                                   0
# DATA_USAGE                                                   180
#
#                                            4
# FXD_ACCT_KEY                          198740
# CAL_DT_KEY                          20190831
# CAL_MTH_KEY                           201908
# MTH_END_FLAG                               Y
# OPENING_STATUS                        ACTIVE
# CLOSING_STATUS                        ACTIVE
# OPENING_SEGMENT                  RESIDENTIAL
# CLOSING_SEGMENT                  RESIDENTIAL
# TECHNOLOGY                              VDSL
# OPENING_BASE                               1
# ADDITIONS                                  0
# DISCONNECTS                                0
# CLOSING_BASE                               1
# GROSS_ADDS                                 0
# CHURN                                      0
# MIGRATIONS                                 0
# TITLE                                   NULL
# SUBURB                                OWHATA
# CITY                                 ROTORUA
# POST_CODE                               3010
# PYMNT_METHOD                    Direct Debit
# SEG_KEY                                    1
# HIST_START_DTTM              29/01/2019 0:00
# HIST_END_DTTM                31/12/9999 0:00
# CURR_IND                                   Y
# PROD_KEY                                2141
# PROD_CD                                  CON
# PROD_DESCR           Services under contract
# PROD_GRP_DESCR                         OTHER
# PROD_TYPE                         SUPSERVICE
# PROD_INTERNAL_DESCR                     NULL
# MLY_FEE_INCL_GST                           0
# CARE_CONTACT                               0
# DATA_USAGE                               170

# %% [markdown]
# Describing the data the min mean stdv

# %%
data.describe().toPandas().transpose()
# Out:
#                          0                     1                    2  \
# summary              count                  mean               stddev
# FXD_ACCT_KEY          2976    163350.99159946237    53481.83488616974
# CAL_DT_KEY            2976           2.0190831E7                  0.0
# CAL_MTH_KEY           2976              201908.0                  0.0
# MTH_END_FLAG          2976                  None                 None
# OPENING_STATUS        2976                  None                 None
# CLOSING_STATUS        2976                  None                 None
# OPENING_SEGMENT       2976                  None                 None
# CLOSING_SEGMENT       2976                  None                 None
# TECHNOLOGY            2976                  None                 None
# OPENING_BASE          2976    0.9250672043010753   0.2633271196680129
# ADDITIONS             2976   0.08702956989247312  0.28192575540787745
# DISCONNECTS           2976    0.0396505376344086  0.19516959792101862
# CLOSING_BASE          2976    0.9724462365591398  0.16371792856535583
# GROSS_ADDS            2976   0.06350806451612903  0.24391552181786497
# CHURN                 2976  0.016129032258064516  0.12599293891327537
# MIGRATIONS            2976                   0.0  0.15118578920369088
# TITLE                 2976                  None                 None
# SUBURB                2976                  None                 None
# CITY                  2749                  None                 None
# POST_CODE             2976     3953.281262812628   2956.6306718767855
# PYMNT_METHOD          2976                  None                 None
# SEG_KEY               2976      1.04502688172043   0.2122044343697978
# HIST_START_DTTM       2976                  None                 None
# HIST_END_DTTM         2976                  None                 None
# CURR_IND              2976                  None                 None
# PROD_KEY              2976     3254.082997311828   1688.3517882361537
# PROD_CD               2976     665.3626373626373    57.30061453193836
# PROD_DESCR            2976                  None                 None
# PROD_GRP_DESCR        2976                  None                 None
# PROD_TYPE             2976                  None                 None
# PROD_INTERNAL_DESCR   2976                  None                 None
# MLY_FEE_INCL_GST      2976    17.495369623655904    37.72638139517564
# CARE_CONTACT          2976    0.2765456989247312   0.4473649797847359
# DATA_USAGE            2976     147.3521505376344   37.926664956219994
#
#                                                 3                       4
# summary                                       min                     max
# FXD_ACCT_KEY                                  853                  233660
# CAL_DT_KEY                               20190831                20190831
# CAL_MTH_KEY                                201908                  201908
# MTH_END_FLAG                                    Y                       Y
# OPENING_STATUS                             ACTIVE               PREACTIVE
# CLOSING_STATUS                             ACTIVE                    NULL
# OPENING_SEGMENT                        ENTERPRISE                     SME
# CLOSING_SEGMENT                        ENTERPRISE                     SME
# TECHNOLOGY                                   ADSL                    VDSL
# OPENING_BASE                                    0                       1
# ADDITIONS                                       0                       1
# DISCONNECTS                                     0                       1
# CLOSING_BASE                                    0                       1
# GROSS_ADDS                                      0                       1
# CHURN                                           0                       1
# MIGRATIONS                                     -1                       1
# TITLE                                        Miss                    NULL
# SUBURB                                 ABBOTSFORD             castlecliff
# CITY                                    ALEXANDRA               WHANGAREI
# POST_CODE                                    1003                 Zealand
# PYMNT_METHOD                                   AP                    Visa
# SEG_KEY                                         1                       3
# HIST_START_DTTM                    1/02/2017 0:00          9/12/2018 0:00
# HIST_END_DTTM                     31/12/9999 0:00         31/12/9999 0:00
# CURR_IND                                        Y                       Y
# PROD_KEY                                       28                    5844
# PROD_CD                                         0                     WAM
# PROD_DESCR            O$10 Discount For 12 Months  Wiring and Maintenance
# PROD_GRP_DESCR                               ADSL                   VOICE
# PROD_TYPE                                PLANTYPE              SUPSERVICE
# PROD_INTERNAL_DESCR                          ADSL                    VDSL
# MLY_FEE_INCL_GST                           -126.5                   218.3
# CARE_CONTACT                                    0                       1
# DATA_USAGE                                      0                     220

# %% [markdown]
# Plotting the scatter plot for finding out co-relations

# %%
from pandas.plotting import scatter_matrix

numeric_features = [t[0] for t in data.dtypes if t[1] == 'int' or t[1] == 'double']

sampled_data = data.select(numeric_features).sample(False, 0.10).toPandas()

#axs = pd.scatter_matrix(sampled_data, figsize=(12, 12));
axs = pd.scatter_matrix(sampled_data, figsize=(12, 12));
# Rotate axis labels and remove axis ticks
n = len(sampled_data.columns)
for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n-1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())

# %% [markdown]
# #Data Selection : Selecting only the relevant columns that are required.

# %%
#Selecting only the columns that are relevant


my_cols = data.select([ 'ADDITIONS','DISCONNECTS','CLOSING_BASE','GROSS_ADDS','MIGRATIONS',
                       'SEG_KEY','PROD_KEY','CARE_CONTACT','DATA_USAGE','TECHNOLOGY','PROD_TYPE','CHURN'])

#Dropping columns that are having null values
final_data=my_cols.na.drop()

# %%
# Print data schema.
final_data.printSchema()


#Sampling the data. This step is to make sure that after the cleaning operation the data is still visible
final_data.take(5)
# Out:
# root
#  |-- ADDITIONS: integer (nullable = true)
#  |-- DISCONNECTS: integer (nullable = true)
#  |-- CLOSING_BASE: integer (nullable = true)
#  |-- GROSS_ADDS: integer (nullable = true)
#  |-- MIGRATIONS: integer (nullable = true)
#  |-- SEG_KEY: integer (nullable = true)
#  |-- PROD_KEY: integer (nullable = true)
#  |-- CARE_CONTACT: integer (nullable = true)
#  |-- DATA_USAGE: integer (nullable = true)
#  |-- TECHNOLOGY: string (nullable = true)
#  |-- PROD_TYPE: string (nullable = true)
#  |-- CHURN: integer (nullable = true)
# [Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=2141, CARE_CONTACT=0, DATA_USAGE=100, TECHNOLOGY='UFB', PROD_TYPE='SUPSERVICE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=1114, CARE_CONTACT=0, DATA_USAGE=150, TECHNOLOGY='UFB', PROD_TYPE='SUPSERVICE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=5051, CARE_CONTACT=0, DATA_USAGE=200, TECHNOLOGY='VDSL', PROD_TYPE='SUPSERVICE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=4852, CARE_CONTACT=0, DATA_USAGE=180, TECHNOLOGY='UFB', PROD_TYPE='PLANTYPE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=2141, CARE_CONTACT=0, DATA_USAGE=170, TECHNOLOGY='VDSL', PROD_TYPE='SUPSERVICE', CHURN=0)]

# %% [markdown]
# # DATA TRANSFORMATION
# Transforming the column data to be used in the algorithm

# %%
#Using Assembler and Vector Indexer to convert string columns to numeric values
from pyspark.ml.feature import (VectorAssembler,VectorIndexer,
                                OneHotEncoder,StringIndexer)

# %%
# First create a string indexer (convert every string into a number, such as 'ADSL','VDSL','FIBRE').
# A number will be assigned to every category in the column.
technology_indexer = StringIndexer(inputCol='TECHNOLOGY',outputCol='TechIndex')

# Now we can one hot encode these numbers. This converts the various outputs into a single vector.
# This makes it easier to process when you have multiple classes.
technology_encoder = OneHotEncoder(inputCol='TechIndex',outputCol='TechVec')

# %%
# First create a string indexer (convert every string into a number, different prod types).
# A number will be assigned to every category in the column.
prodcd_indexer = StringIndexer(inputCol='PROD_TYPE',outputCol='ProdIndex')

# Now we can one hot encode these numbers. This converts the various outputs into a single vector.
# This makes it easier to process when you have multiple classes.
prodcd_encoder = OneHotEncoder(inputCol='ProdIndex',outputCol='ProdVec')

# %%
# Now we can assemble all of this as one vector in the features column. 
assembler = VectorAssembler(inputCols=['TechVec',
 'ProdVec','ADDITIONS','DISCONNECTS','CLOSING_BASE'],outputCol='features')

# %% [markdown]
# # Running the Algorithm

# %%
from pyspark.ml.classification import LogisticRegression

# %% [markdown]
# Pipelines
# A pipeline sets stages for different steps. Let's see an example of how to use pipelines.

# %%
from pyspark.ml import Pipeline

# %%
# Note that survived is a categorial variable but didn't require any transformation.
# That's because it's already in the format of 1's and 0's. 
log_churn_prd = LogisticRegression(featuresCol='features',labelCol='CHURN')

# %%
# Lists everything we want to do. Index data, encode data, assemble data and then pass in the actual model.
pipeline = Pipeline(stages=[technology_indexer,prodcd_indexer,
                           technology_encoder,prodcd_encoder,
                           assembler,log_churn_prd])

# %%
# Train/test split. 
train_churn_data, test_churn_data = final_data.randomSplit([0.7,.3])

# %%
# Print data schema.
final_data.printSchema()

final_data.take(5)


# Print data schema.
train_churn_data.printSchema()
train_churn_data.take(5)
# Out:
# root
#  |-- ADDITIONS: integer (nullable = true)
#  |-- DISCONNECTS: integer (nullable = true)
#  |-- CLOSING_BASE: integer (nullable = true)
#  |-- GROSS_ADDS: integer (nullable = true)
#  |-- MIGRATIONS: integer (nullable = true)
#  |-- SEG_KEY: integer (nullable = true)
#  |-- PROD_KEY: integer (nullable = true)
#  |-- CARE_CONTACT: integer (nullable = true)
#  |-- DATA_USAGE: integer (nullable = true)
#  |-- TECHNOLOGY: string (nullable = true)
#  |-- PROD_TYPE: string (nullable = true)
#  |-- CHURN: integer (nullable = true)
#
# root
#  |-- ADDITIONS: integer (nullable = true)
#  |-- DISCONNECTS: integer (nullable = true)
#  |-- CLOSING_BASE: integer (nullable = true)
#  |-- GROSS_ADDS: integer (nullable = true)
#  |-- MIGRATIONS: integer (nullable = true)
#  |-- SEG_KEY: integer (nullable = true)
#  |-- PROD_KEY: integer (nullable = true)
#  |-- CARE_CONTACT: integer (nullable = true)
#  |-- DATA_USAGE: integer (nullable = true)
#  |-- TECHNOLOGY: string (nullable = true)
#  |-- PROD_TYPE: string (nullable = true)
#  |-- CHURN: integer (nullable = true)
# [Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=28, CARE_CONTACT=0, DATA_USAGE=150, TECHNOLOGY='ADSL', PROD_TYPE='PLANTYPE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=28, CARE_CONTACT=0, DATA_USAGE=150, TECHNOLOGY='ADSL', PROD_TYPE='PLANTYPE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=28, CARE_CONTACT=0, DATA_USAGE=150, TECHNOLOGY='ADSL', PROD_TYPE='PLANTYPE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=28, CARE_CONTACT=0, DATA_USAGE=150, TECHNOLOGY='ADSL', PROD_TYPE='PLANTYPE', CHURN=0),
#  Row(ADDITIONS=0, DISCONNECTS=0, CLOSING_BASE=1, GROSS_ADDS=0, MIGRATIONS=0, SEG_KEY=1, PROD_KEY=28, CARE_CONTACT=0, DATA_USAGE=180, TECHNOLOGY='ADSL', PROD_TYPE='PLANTYPE', CHURN=0)]

# %%
# Note pipeline. Call it as you would call a machine learning object.
fit_model = pipeline.fit(train_churn_data)

# %%
# Transform test data. 
results = fit_model.transform(test_churn_data)

# %% [markdown]
# # Evaluation

# %%
# Evaluate the model using the binary classifer.
from pyspark.ml.evaluation import BinaryClassificationEvaluator

my_eval = BinaryClassificationEvaluator(rawPredictionCol='prediction',
                                       labelCol='CHURN')

# %%
# If we select the actual and predicted results, we can see that some predictions were correct while others were wrong.
results.select('CHURN','prediction','probability').show()

results
results.show()
# Out:
# +-----+----------+--------------------+
# |CHURN|prediction|         probability|
# +-----+----------+--------------------+
# |    0|       0.0|[0.99999999999916...|
# |    0|       0.0|[0.99999999999852...|
# |    0|       0.0|[0.99999999999916...|
# |    0|       0.0|[0.99999999999916...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999870...|
# |    0|       0.0|[0.99999999999852...|
# |    0|       0.0|[0.99999999999852...|
# |    0|       0.0|[0.99999999999852...|
# |    0|       0.0|[0.99999999999852...|
# |    0|       0.0|[0.99999999999852...|
# |    0|       0.0|[0.99999999999852...|
# +-----+----------+--------------------+
# only showing top 20 rows
#
# +---------+-----------+------------+----------+----------+-------+--------+------------+----------+----------+---------+-----+---------+---------+-------------+---------+-------------------+--------------------+--------------------+----------+
# |ADDITIONS|DISCONNECTS|CLOSING_BASE|GROSS_ADDS|MIGRATIONS|SEG_KEY|PROD_KEY|CARE_CONTACT|DATA_USAGE|TECHNOLOGY|PROD_TYPE|CHURN|TechIndex|ProdIndex|      TechVec|  ProdVec|           features|       rawPrediction|         probability|prediction|
# +---------+-----------+------------+----------+----------+-------+--------+------------+----------+----------+---------+-----+---------+---------+-------------+---------+-------------------+--------------------+--------------------+----------+
# |        0|          0|           1|         0|         0|      1|      28|           1|        50|      ADSL| PLANTYPE|    0|      2.0|      1.0|    (2,[],[])|(1,[],[])|      (6,[5],[1.0])|[27.8138038980089...|[0.99999999999916...|       0.0|
# |        0|          0|           1|         0|         0|      1|      43|           0|       150|       UFB| PLANTYPE|    0|      0.0|      1.0|(2,[0],[1.0])|(1,[],[])|(6,[0,5],[1.0,1.0])|[27.2428119925005...|[0.99999999999852...|       0.0|
# |        0|          0|           1|         0|         0|      1|      46|           0|       170|      ADSL| PLANTYPE|    0|      2.0|      1.0|    (2,[],[])|(1,[],[])|      (6,[5],[1.0])|[27.8138038980089...|[0.99999999999916...|       0.0|
# |        0|          0|           1|         0|         0|      1|      47|           0|       170|      ADSL| PLANTYPE|    0|      2.0|      1.0|    (2,[],[])|(1,[],[])|      (6,[5],[1.0])|[27.8138038980089...|[0.99999999999916...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           0|       100|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           0|       150|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           0|       150|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           0|       170|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           0|       180|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           0|       180|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           0|       180|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           1|       150|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           1|       150|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      54|           1|       170|      VDSL| PLANTYPE|    0|      1.0|      1.0|(2,[1],[1.0])|(1,[],[])|(6,[1,5],[1.0,1.0])|[27.3687526254169...|[0.99999999999870...|       0.0|
# |        0|          0|           1|         0|         0|      1|      64|           0|       150|       UFB| PLANTYPE|    0|      0.0|      1.0|(2,[0],[1.0])|(1,[],[])|(6,[0,5],[1.0,1.0])|[27.2428119925005...|[0.99999999999852...|       0.0|
# |        0|          0|           1|         0|         0|      1|      86|           0|       100|       UFB| PLANTYPE|    0|      0.0|      1.0|(2,[0],[1.0])|(1,[],[])|(6,[0,5],[1.0,1.0])|[27.2428119925005...|[0.99999999999852...|       0.0|
# |        0|          0|           1|         0|         0|      1|      87|           0|       150|       UFB| PLANTYPE|    0|      0.0|      1.0|(2,[0],[1.0])|(1,[],[])|(6,[0,5],[1.0,1.0])|[27.2428119925005...|[0.99999999999852...|       0.0|
# |        0|          0|           1|         0|         0|      1|      87|           0|       150|       UFB| PLANTYPE|    0|      0.0|      1.0|(2,[0],[1.0])|(1,[],[])|(6,[0,5],[1.0,1.0])|[27.2428119925005...|[0.99999999999852...|       0.0|
# |        0|          0|           1|         0|         0|      1|      87|           0|       200|       UFB| PLANTYPE|    0|      0.0|      1.0|(2,[0],[1.0])|(1,[],[])|(6,[0,5],[1.0,1.0])|[27.2428119925005...|[0.99999999999852...|       0.0|
# |        0|          0|           1|         0|         0|      1|      87|           1|       200|       UFB| PLANTYPE|    0|      0.0|      1.0|(2,[0],[1.0])|(1,[],[])|(6,[0,5],[1.0,1.0])|[27.2428119925005...|[0.99999999999852...|       0.0|
# +---------+-----------+------------+----------+----------+-------+--------+------------+----------+----------+---------+-----+---------+---------+-------------+---------+-------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %% [markdown]
# AUC Evaluation

# %%
AUC = my_eval.evaluate(results)

AUC
# Out:
# 0.9459396751740139

# %% [markdown]
# # Data Visualisation
# PySpark doesn't allow you to plot data directly. Instead, the simplest way to visualise data is to convert the DataFrame into an array, then use Python's extensive libraries (such as Matplotlib) to visualise the data appropriately. Because of this, the sky's the limit when it comes to data visualisation! Here's a simple example:

# %%
# Import the relevant Python libraries.
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Convert sex to an array using Numpy and plot it using pyplot. 
TechArr = np.array(data.select('TECHNOLOGY').collect())
plt.hist(TechArr)
plt.show()

# Because you can interact with Spark using SQL, you can also filter the data you see. 
# For example, age has some null values. We can remove all null values before visualising the data.
DATA_USAGE_Arr = np.array(data.filter('DATA_USAGE >100').select('DATA_USAGE').collect())
plt.hist(DATA_USAGE_Arr)
plt.show()

# %% [markdown]
# # TESTING

# %%
# Not all interpretation has to be visualisations. You can also gain a lot of information with text.
# For example, here we're seeing how much variance our model could account for.
# According to this, the model got 164/209 correct. 
totalResults = results.select('CHURN','prediction')

correctResults = totalResults.filter(totalResults['CHURN'] == totalResults['prediction'])

countTR = totalResults.count()
print("Correct: " + str(countTR))

countTC = correctResults.count()
print("Total Correct: " + str(countTC))
# Out:
# Correct: 882
# Total Correct: 873
